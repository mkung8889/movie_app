# %% [markdown]
# ### Summary of Random Forest Models

# %% [markdown]
# * As expected, random forest is an inaccurate predicter of movie rating regarless of features used.

# %% [markdown]
# #### Model 1

# %% [markdown]
# * 1998 Dataset
# * Features: user_id, item_id, age, occupation, gender
# * Label Encoder
# * 33.688% accuracy
# * 1.83468 MSE

# %%
from IPython.display import Image
Image("../images/rf1998LE.png")

# %% [markdown]
# #### Model 2

# %% [markdown]
# * 1998 Dataset
# * Features: user_id, item_id, age, occupation, gender, genres
# * One Hot Encoding
# * 35.372% accuracy
# * 1.58776 MSE

# %%
from IPython.display import Image
Image("../images/rf1998OHE.png")

# %% [markdown]
# #### Model 3

# %% [markdown]
# * 2018 100k Dataset
# * Features: user_id, item_id, genres, movie release year
# * One Hot Encoding
# * 33.674% accuracy
# * 1.7371 MSE

# %%
from IPython.display import Image
Image("../images/rf2018OHE.png")

# %% [markdown]
# #### Model 4

# %% [markdown]
# * 2018 100k Dataset
# * Features: user_id, item_id, genres
# * One Hot Encoding
# * 34.2853% accuracy
# * 1.6977270022610973 RMSE

# %%
from IPython.display import Image
Image("../images/RF2018OHE.png")
